# %% [markdown]
# <a href="https://colab.research.google.com/github/YasinnSoylu/IsolationForest-pycaret-Credit_Card_Fraud_Detection/blob/main/Credit_Card_Fraud_Detection_DecisionTreeClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![3-Credit-Card-Fraud-Detection.png](data:image/png;base64,...)

# %% [markdown]
# ## In this notebook we will perform the following task:
# - Data Analysis
# - Feature Engineering
# - Model Building and Prediction using ML Techniques
# - Model Building and Prediction using PyCaret(Auto ML)

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import scipy
from sklearn.metrics import classification_report,accuracy_score
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Importing Libraries for Outlier Detection

# %%
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM

# %% [markdown]
# ### Reading our Dataset

# %%
df= pd.read_csv("creditcard.csv")

# %% [markdown]
# ### Data Analysis

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.dropna(inplace=True)

# %% [markdown]
# #### Let us see what is the shape of Normal and Fraud data set

# %%
fraud_people = df[df['Class']==1]
normal_people = df[df['Class']==0]

# %%
columns = df.columns.tolist()
# Making our Independent Features
columns = [var for var in columns if var not in ["Class"]]
# Making our Dependent Variable
target = "Class"
X= df[columns]
y= df[target]

# %% [markdown]
# ### Splitting the data

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %% [markdown]
# # DecisionTree

# %%
model = DecisionTreeClassifier(max_depth=10)

model.fit(x_train, y_train)

ypred = model.predict(x_test)


accuracy_score(y_test, ypred)
# Out:
# 0.9995201479348805

# %%
from sklearn import tree
plt.figure(figsize=(20,10))

tree.plot_tree(model,filled = True)
plt.show()
